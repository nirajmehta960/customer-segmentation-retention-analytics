# %% [markdown]
# # Notebook 03: RFM Analysis
# Compute RFM scores, assign rule-based segments, generate segment profiles, and save all EDA charts.
#
# **Input:** `data/preprocessed/online_retail_preprocessed.csv`
# **Output:** `data/featured/customer_rfm.csv`, `data/featured/segment_profiles.csv`, `images/eda_charts/`

# %%
import os
import sys
import pandas as pd
if os.path.basename(os.getcwd()) == 'notebooks':
    os.chdir('..')
sys.path.insert(0, '.')

from src.rfm_analysis import run_rfm_pipeline

df = pd.read_csv('data/preprocessed/online_retail_preprocessed.csv')
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
rfm = run_rfm_pipeline(df=df, save_path='data/featured/customer_rfm.csv')
rfm.head(10)
# Out:
# RFM segments saved to data/featured/customer_rfm.csv
# segment
# Loyal Customers        1034
# At Risk                 759
# Lost / Hibernating      721
# Can't Lose Them         565
# Champions               489
# Need Attention          454
# New Customers           234
# Potential Loyalists      82
#
# Segment profiles saved to /Users/nirajmehta/Documents/Data Analyst Projects/customer-segmentation-retention-analytics/data/featured/segment_profiles.csv
#             segment  customer_count  avg_recency  avg_frequency  avg_monetary  total_revenue  pct_customers  pct_revenue
#           Champions             489          7.4           15.5       9047.80     4424373.61           11.3         49.8
#     Loyal Customers            1034         22.6            5.2       2088.74     2159756.49           23.8         24.3
#             At Risk             759         84.0            3.3       1255.39      952843.70           17.5         10.7
#     Can't Lose Them             565        232.4            2.2        805.45      455080.93           13.0          5.1
#      Need Attention             454         62.3            1.2        695.16      315604.79           10.5          3.6
#       New Customers             234         10.0            1.6       1226.13      286914.79            5.4          3.2
#  Lost / Hibernating             721        202.4            1.0        261.82      188768.65           16.6          2.1
# Potential Loyalists              82         33.9            1.7       1266.66      103865.93            1.9          1.2
#    CustomerID       last_purchase  frequency  monetary  recency  r_score  \
# 0       12346 2011-01-18 10:01:00          1  77183.60      326        1
# 1       12347 2011-12-07 15:52:00          7   4310.00        2        4
# 2       12348 2011-09-25 13:13:00          4   1797.24       75        2
# 3       12349 2011-11-21 09:51:00          1   1757.55       19        3
# 4       12350 2011-02-02 16:01:00          1    334.40      310        1
# 5       12352 2011-11-03 14:37:00          8   2506.04       36        3
# 6       12353 2011-05-19 17:47:00          1     89.00      204        1
# 7       12354 2011-04-21 13:11:00          1   1079.40      232        1
# 8       12355 2011-05-09 13:49:00          1    459.40      214        1
# 9       12356 2011-11-17 08:40:00          3   2811.43       23        3
#
#    f_score  m_score              segment rfm_segment
# 0        1        4       Need Attention       1-1-4
# 1        4        4            Champions       4-4-4
# 2        3        4              At Risk       2-3-4
# 3        1        4  Potential Loyalists       3-1-4
# 4        1        2   Lost / Hibernating       1-1-2
# 5        4        4      Loyal Customers       3-4-4
# 6        1        1   Lost / Hibernating       1-1-1
# 7        1        3       Need Attention       1-1-3
# 8        1        2   Lost / Hibernating       1-1-2
# 9        3        4      Loyal Customers       3-3-4

# %%
# Segment profile summary (load from saved CSV)
profile = pd.read_csv('data/featured/segment_profiles.csv')
profile
# Out:
#                segment  customer_count  avg_recency  avg_frequency  \
# 0            Champions             489          7.4           15.5
# 1      Loyal Customers            1034         22.6            5.2
# 2              At Risk             759         84.0            3.3
# 3      Can't Lose Them             565        232.4            2.2
# 4       Need Attention             454         62.3            1.2
# 5        New Customers             234         10.0            1.6
# 6   Lost / Hibernating             721        202.4            1.0
# 7  Potential Loyalists              82         33.9            1.7
#
#    avg_monetary  total_revenue  pct_customers  pct_revenue
# 0       9047.80     4424373.61           11.3         49.8
# 1       2088.74     2159756.49           23.8         24.3
# 2       1255.39      952843.70           17.5         10.7
# 3        805.45      455080.93           13.0          5.1
# 4        695.16      315604.79           10.5          3.6
# 5       1226.13      286914.79            5.4          3.2
# 6        261.82      188768.65           16.6          2.1
# 7       1266.66      103865.93            1.9          1.2

# %%
# Generate and save all EDA charts to images/eda_charts/
from src.visualizations import generate_all_eda_charts

generate_all_eda_charts(df, rfm, save_dir='images/eda_charts')
# Out:
# Generating EDA charts...
#   ✓ monthly_revenue.png
#   ✓ revenue_by_country.png
#   ✓ revenue_per_customer_by_country.png
#   ✓ top_products_revenue.png
#   ✓ top_products_quantity.png
#   ✓ day_hour_patterns.png
#   ✓ rfm_distributions.png
#   ✓ order_frequency_distribution.png
#   ✓ segment_distribution.png
#   ✓ revenue_by_segment.png
#   ✓ segment_scatter.png
#   ✓ pareto_curve.png
# Done — 12 charts saved to images/eda_charts/
